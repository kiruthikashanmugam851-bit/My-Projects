# %% [markdown]
# <a href="https://colab.research.google.com/github/kiruthikashanmugam851-bit/My-Projects/blob/main/All%20India%20Pincode%20collab%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ***ALL INDIA PINCODE DIRECTORY***

# %% [markdown]
#  ### Domain
#   **GEOGRAPHICAL AND POSTAL DATA**

# %% [markdown]
# ### **Problem Statement** :
#
#  The All India Pincode Directory focuses on exploring and understanding the structure of India’s postal system using the official PIN code.“This project is to analyze India’s postal network using the All India Pincode Directory dataset to understand postal coverage, delivery service availability, and regional distribution patterns.
#
# ### **Dataset Info :**
#
#  ▶ All India Pincode Dataset
#
#  ▶  Rows: 20000+rows
#
# ▶  Columns : 10-15
#
# ▶  Location :Geographic region ( INDIA)
#
# ▶ Year/Timeline : Data collected during the period 2020 to 2025

# %% [markdown]
# ## **Problem Definition and Dataset Selection**

# %%
# Import Libraries
# Importing Pandas
import pandas as pd

# %% [markdown]
# **Load CSV File**

# %%
# Loading the dataset and creating Dataframe

url = "https://github.com/kiruthikashanmugam851-bit/My-Projects/raw/refs/heads/main/All%20India%20Pincode%20Directory.csv"
df = pd.read_csv(url)

# %% [markdown]
# ## **Dataset description**

# %%
# Essential information of DataFrame
# view datafreame
df
# Out:
#                 circlename             regionname  \
# 0         Telangana Circle       Hyderabad Region
# 1         Telangana Circle       Hyderabad Region
# 2         Telangana Circle       Hyderabad Region
# 3         Telangana Circle       Hyderabad Region
# 4         Telangana Circle       Hyderabad Region
# ...                    ...                    ...
# 165622  West Bengal Circle    South Bengal Region
# 165623  West Bengal Circle    South Bengal Region
# 165624  West Bengal Circle    South Bengal Region
# 165625  West Bengal Circle    South Bengal Region
# 165626    Telangana Circle  Hyderabad City Region
#
#                          divisionname                       officename  \
# 0                   Adilabad Division                     Kothimir B.O
# 1                   Adilabad Division                     Papanpet B.O
# 2                   Adilabad Division                       Kukuda B.O
# 3                   Adilabad Division                     Bareguda B.O
# ...

# %%
# Statistical summary
df.head()
# Out:
#          circlename        regionname       divisionname    officename  \
# 0  Telangana Circle  Hyderabad Region  Adilabad Division  Kothimir B.O
# 1  Telangana Circle  Hyderabad Region  Adilabad Division  Papanpet B.O
# 2  Telangana Circle  Hyderabad Region  Adilabad Division    Kukuda B.O
# 3  Telangana Circle  Hyderabad Region  Adilabad Division  Bareguda B.O
# 4  Telangana Circle  Hyderabad Region  Adilabad Division     Mosam B.O
#
#    pincode officetype  delivery                district  statename  \
# 0   504273         BO  Delivery  KUMURAM BHEEM ASIFABAD  TELANGANA
# 1   504299         BO  Delivery  KUMURAM BHEEM ASIFABAD  TELANGANA
# 2   504299         BO  Delivery  KUMURAM BHEEM ASIFABAD  TELANGANA
# 3   504296         BO  Delivery  KUMURAM BHEEM ASIFABAD  TELANGANA
# 4   504296         BO  Delivery  KUMURAM BHEEM ASIFABAD  TELANGANA
#
#      latitude   longitude
# 0  19.3638689  79.5376658
# 1  19.4764899   79.583923
# 2         NaN         NaN
# ...

# %%
# Info of the Data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165627 entries, 0 to 165626
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   circlename    165627 non-null  object
#  1   regionname    165312 non-null  object
#  2   divisionname  165627 non-null  object
#  3   officename    165627 non-null  object
#  4   pincode       165627 non-null  int64
#  5   officetype    165627 non-null  object
#  6   delivery      165627 non-null  object
#  7   district      164912 non-null  object
#  8   statename     164912 non-null  object
#  9   latitude      153620 non-null  object
#  10  longitude     153625 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 13.9+ MB

# %%
# Shape of Dataset()
# Rows and Columns

df.shape
# Out:
# (165627, 11)

# %%
# duplicates
df.duplicated
# Out:
# <bound method DataFrame.duplicated of                 circlename             regionname  \
# 0         Telangana Circle       Hyderabad Region
# 1         Telangana Circle       Hyderabad Region
# 2         Telangana Circle       Hyderabad Region
# 3         Telangana Circle       Hyderabad Region
# 4         Telangana Circle       Hyderabad Region
# ...                    ...                    ...
# 165622  West Bengal Circle    South Bengal Region
# 165623  West Bengal Circle    South Bengal Region
# 165624  West Bengal Circle    South Bengal Region
# 165625  West Bengal Circle    South Bengal Region
# 165626    Telangana Circle  Hyderabad City Region
#
#                          divisionname                       officename  \
# 0                   Adilabad Division                     Kothimir B.O
# 1                   Adilabad Division                     Papanpet B.O
# 2                   Adilabad Division                       Kukuda B.O
# ...

# %%
# Describe the dataset
df.describe(include= 'all')
# Out:
#                   circlename          regionname     divisionname officename  \
# count                 165627              165312           165627     165627
# unique                    24                  52              482     145086
# top     Uttar Pradesh Circle  DivReportingCircle  Bastar Division  Rampur BO
# freq                   17997               30777             1598         57
# mean                     NaN                 NaN              NaN        NaN
# std                      NaN                 NaN              NaN        NaN
# min                      NaN                 NaN              NaN        NaN
# 25%                      NaN                 NaN              NaN        NaN
# 50%                      NaN                 NaN              NaN        NaN
# 75%                      NaN                 NaN              NaN        NaN
# max                      NaN                 NaN              NaN        NaN
#
# ...
